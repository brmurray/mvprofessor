# %%
import numpy as np
from numpy.random import default_rng
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import networkx as nx
import geopandas
import folium
from shapely.geometry import Point
from geographiclib.geodesic import Geodesic

from mvprofessor.config import int_data_dir
from mvprofessor.custom_funcs import get_endpoints, make_blobs

# %%
gdf = pd.read_pickle(int_data_dir/'professor.pkl')

gdf.head()
# Out:
#             Shape__Length  OBJECTID    NODE_ID  \
# SECTION_ID
# 18618932       134.049843     41360   18566552
# 18618947       153.899170     41361   18566381
# 18618995       442.837667     41362  150296014
# 18619003       231.466259     41363   18618825
# 18619048       131.991056     41364   18566097
#
#                                                      geometry    node_id  \
# SECTION_ID
# 18618932    LINESTRING (238325.856 3813818.832, 238325.933...   18566552
# 18618947    LINESTRING (238627.281 3813533.183, 238669.854...   18566381
# 18618995    LINESTRING (237900.554 3813649.375, 237765.865...  150296014
# 18619003    LINESTRING (238296.419 3814311.838, 238296.293...   18618825
# 18619048    LINESTRING (238192.943 3813743.144, 238194.086...   18566097
#
#             randc
# SECTION_ID
# 18618932      705
# 18618947      806
# 18618995      136
# 18619003      438
# 18619048      598

# %%
gdf.explore(column='randc',cmap='gist_rainbow',legend=False, name="DRPEP Line Sections")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fa8a53b13859cf4d9e99dca86864ab52 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fa8a53b13859cf4d9e99dca86864ab52&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fa8a53b13859cf4d9e99dca86864ab52 = L.map(
#                 &quot;map_fa8a53b13859cf4d9e99dca86864ab52&quot;,
#                 {
#                     center: [34.43233855303059, -119.85631828523425],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_fa8a53b13859cf4d9e99dca86864ab52);
#
#
#
#
#
#             var tile_layer_aea1e50fbdabadd01efff8f023b5a0f4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fa8a53b13859cf4d9e99dca86864ab52);
#
#
#             map_fa8a53b13859cf4d9e99dca86864ab52.fitBounds(
#                 [[34.42682529040294, -119.87168579645176], [34.437851815658235, -119.84095077401675]],
#                 {}
#             );
#
#
#         function geo_json_e1fa17743a4d79924145af44a65bca31_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;:
#                     return {&quot;color&quot;: &quot;#00ecff&quot;, &quot;fillColor&quot;: &quot;#00ecff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;: case &quot;97&quot;:
#                     return {&quot;color&quot;: &quot;#0074ff&quot;, &quot;fillColor&quot;: &quot;#0074ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;:
#                     return {&quot;color&quot;: &quot;#ff7300&quot;, &quot;fillColor&quot;: &quot;#ff7300&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;: case &quot;19&quot;:
#                     return {&quot;color&quot;: &quot;#26ff00&quot;, &quot;fillColor&quot;: &quot;#26ff00&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;4&quot;: case &quot;12&quot;: case &quot;51&quot;:
#                     return {&quot;color&quot;: &quot;#00ff97&quot;, &quot;fillColor&quot;: &quot;#00ff97&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;:
#                     return {&quot;color&quot;: &quot;#00ff61&quot;, &quot;fillColor&quot;: &quot;#00ff61&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;6&quot;:
#                     return {&quot;color&quot;: &quot;#00ffcc&quot;, &quot;fillColor&quot;: &quot;#00ffcc&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;7&quot;: case &quot;158&quot;:
#                     return {&quot;color&quot;: &quot;#00ff6c&quot;, &quot;fillColor&quot;: &quot;#00ff6c&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;8&quot;:
#                     return {&quot;color&quot;: &quot;#00ffd7&quot;, &quot;fillColor&quot;: &quot;#00ffd7&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;9&quot;: case &quot;89&quot;:
#                     return {&quot;color&quot;: &quot;#ff5300&quot;, &quot;fillColor&quot;: &quot;#ff5300&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;10&quot;:
#                     return {&quot;color&quot;: &quot;#bc00ff&quot;, &quot;fillColor&quot;: &quot;#bc00ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;11&quot;: case &quot;88&quot;:
#                     return {&quot;color&quot;: &quot;#4a00ff&quot;, &quot;fillColor&quot;: &quot;#4a00ff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;13&quot;:
#                     return {&quot;color&quot;: &quot;#00ffb7&quot;, &quot;fillColor&quot;: &quot;#00ffb7&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;14&quot;:
#                     return {&quot;color&quot;: &quot;#f9ff00&quot;, &quot;fillColor&quot;: &quot;#f9ff00&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;15&quot;: case &quot;17&quot;: case &quot;42&quot;: case &quot;72&quot;:
#                     return {&quot
